# %%
import import_ipynb
# %run utils.ipynb
# Out:
# 2025-01-03 11:30:19.149191: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-01-03 11:30:19.150733: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-01-03 11:30:19.154592: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-01-03 11:30:19.162326: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1735871419.176636    5121 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1735871419.181027    5121 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-01-03 11:30:19.195768: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# Load the datasets
import pandas as pd
import os
from sklearn.preprocessing import LabelEncoder, StandardScaler

def load_and_explore_datasets(folder_path):
    train_file = os.path.join(folder_path, "train.csv")
    val_file = os.path.join(folder_path, "val.csv")
    test_file = os.path.join(folder_path, "test.csv")

    train_data = pd.read_csv(train_file)
    val_data = pd.read_csv(val_file)
    test_data = pd.read_csv(test_file)

    train_data['Label'] = train_data['attack_cat']
    val_data['Label'] = val_data['attack_cat']
    test_data['Label'] = test_data['attack_cat']

    print("Train Dataset:")
    print(train_data.info())
    print(train_data.head(), "\n")

    print("Validation Dataset:")
    print(val_data.info())
    print(val_data.head(), "\n")

    print("Test Dataset:")
    print(test_data.info())
    print(test_data.head(), "\n")

    print("Missing values in Train dataset:")
    print(train_data.isnull().sum(), "\n")

    print("Missing values in Validation dataset:")
    print(val_data.isnull().sum(), "\n")

    print("Missing values in Test dataset:")
    print(test_data.isnull().sum(), "\n")

    print("Class distribution in Train dataset:")
    print(train_data['Label'].value_counts(), "\n")

    print("Class distribution in Validation dataset:")
    print(val_data['Label'].value_counts(), "\n")

    print("Class distribution in Test dataset:")
    print(test_data['Label'].value_counts(), "\n")

    return train_data, val_data, test_data

folder_path = "./UNSW_NB15/"
train_data, val_data, test_data = load_and_explore_datasets(folder_path)
# Out:
# Train Dataset:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180371 entries, 0 to 180370
# Data columns (total 46 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   id                 180371 non-null  int64
#  1   dur                180371 non-null  float64
#  2   proto              180371 non-null  object
#  3   service            180371 non-null  object
#  4   state              180371 non-null  object
#  5   spkts              180371 non-null  int64
#  6   dpkts              180371 non-null  int64
#  7   sbytes             180371 non-null  int64
#  8   dbytes             180371 non-null  int64
#  9   rate               180371 non-null  float64
#  10  sttl               180371 non-null  int64
#  11  dttl               180371 non-null  int64
#  12  sload              180371 non-null  float64
#  13  dload              180371 non-null  float64
#  14  sloss              180371 non-null  int64
#  15  dloss              180371 non-null  int64
#  16  sinpkt             180371 non-null  float64
#  17  dinpkt             180371 non-null  float64
#  18  sjit               180371 non-null  float64
#  19  djit               180371 non-null  float64
#  20  swin               180371 non-null  int64
#  21  stcpb              180371 non-null  int64
#  22  dtcpb              180371 non-null  int64
#  23  dwin               180371 non-null  int64
#  24  tcprtt             180371 non-null  float64
#  25  synack             180371 non-null  float64
#  26  ackdat             180371 non-null  float64
#  27  smean              180371 non-null  int64
#  28  dmean              180371 non-null  int64
#  29  trans_depth        180371 non-null  int64
#  30  response_body_len  180371 non-null  int64
#  31  ct_srv_src         180371 non-null  int64
#  32  ct_state_ttl       180371 non-null  int64
#  33  ct_dst_ltm         180371 non-null  int64
#  34  ct_src_dport_ltm   180371 non-null  int64
#  35  ct_dst_sport_ltm   180371 non-null  int64
#  36  ct_dst_src_ltm     180371 non-null  int64
#  37  is_ftp_login       180371 non-null  int64
#  38  ct_ftp_cmd         180371 non-null  int64
#  39  ct_flw_http_mthd   180371 non-null  int64
#  40  ct_src_ltm         180371 non-null  int64
#  41  ct_srv_dst         180371 non-null  int64
#  42  is_sm_ips_ports    180371 non-null  int64
#  43  attack_cat         180371 non-null  object
#  44  label              180371 non-null  int64
#  45  Label              180371 non-null  object
# dtypes: float64(11), int64(30), object(5)
# memory usage: 63.3+ MB
# None
#        id       dur proto service state  spkts  dpkts  sbytes  dbytes  \
# 0   40306  0.050984   tcp       -   FIN     42     42    2646   23508
# 1   54787  0.000008   pgm       -   INT      2      0     200       0
# 2  162958  0.000003   udp     dns   INT      2      0     114       0
# 3  138931  0.000003   udp     dns   INT      2      0     114       0
# 4   31409  1.431244   tcp    http   FIN     14     18    1684   10168
#
#             rate  ...  ct_dst_src_ltm  is_ftp_login  ct_ftp_cmd  \
# 0    1627.961748  ...               1             0           0
# 1  125000.000300  ...               6             0           0
# 2  333333.321500  ...              17             0           0
# 3  333333.321500  ...              36             0           0
# 4      21.659479  ...               1             0           0
#
#    ct_flw_http_mthd  ct_src_ltm  ct_srv_dst  is_sm_ips_ports  attack_cat  \
# 0                 0           3           4                0      Normal
# 1                 0           8           6                0    Analysis
# 2                 0          18          17                0     Generic
# 3                 0          32          36                0     Generic
# 4                 1           1           2                0      Normal
#
#    label     Label
# 0      0    Normal
# 1      1  Analysis
# 2      1   Generic
# 3      1   Generic
# 4      0    Normal
#
# [5 rows x 46 columns]
#
# Validation Dataset:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38650 entries, 0 to 38649
# Data columns (total 46 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 38650 non-null  int64
#  1   dur                38650 non-null  float64
#  2   proto              38650 non-null  object
#  3   service            38650 non-null  object
#  4   state              38650 non-null  object
#  5   spkts              38650 non-null  int64
#  6   dpkts              38650 non-null  int64
#  7   sbytes             38650 non-null  int64
#  8   dbytes             38650 non-null  int64
#  9   rate               38650 non-null  float64
#  10  sttl               38650 non-null  int64
#  11  dttl               38650 non-null  int64
#  12  sload              38650 non-null  float64
#  13  dload              38650 non-null  float64
#  14  sloss              38650 non-null  int64
#  15  dloss              38650 non-null  int64
#  16  sinpkt             38650 non-null  float64
#  17  dinpkt             38650 non-null  float64
#  18  sjit               38650 non-null  float64
#  19  djit               38650 non-null  float64
#  20  swin               38650 non-null  int64
#  21  stcpb              38650 non-null  int64
#  22  dtcpb              38650 non-null  int64
#  23  dwin               38650 non-null  int64
#  24  tcprtt             38650 non-null  float64
#  25  synack             38650 non-null  float64
#  26  ackdat             38650 non-null  float64
#  27  smean              38650 non-null  int64
#  28  dmean              38650 non-null  int64
#  29  trans_depth        38650 non-null  int64
#  30  response_body_len  38650 non-null  int64
#  31  ct_srv_src         38650 non-null  int64
#  32  ct_state_ttl       38650 non-null  int64
#  33  ct_dst_ltm         38650 non-null  int64
#  34  ct_src_dport_ltm   38650 non-null  int64
#  35  ct_dst_sport_ltm   38650 non-null  int64
#  36  ct_dst_src_ltm     38650 non-null  int64
#  37  is_ftp_login       38650 non-null  int64
#  38  ct_ftp_cmd         38650 non-null  int64
#  39  ct_flw_http_mthd   38650 non-null  int64
#  40  ct_src_ltm         38650 non-null  int64
#  41  ct_srv_dst         38650 non-null  int64
#  42  is_sm_ips_ports    38650 non-null  int64
#  43  attack_cat         38650 non-null  object
#  44  label              38650 non-null  int64
#  45  Label              38650 non-null  object
# dtypes: float64(11), int64(30), object(5)
# memory usage: 13.6+ MB
# None
#        id        dur proto service state  spkts  dpkts  sbytes  dbytes  \
# 0   88453  59.656837  ospf       -   REQ     48      0    5184       0
# 1   79299   0.828856   tcp       -   FIN     10      6    2530     268
# 2  122963   0.000009   udp     dns   INT      2      0     114       0
# 3   25057   1.008807   tcp    http   FIN     14     18    1684   10168
# 4   12808   1.187773   tcp       -   FIN    122    126    7814   16912
#
#             rate  ...  ct_dst_src_ltm  is_ftp_login  ct_ftp_cmd  \
# 0       0.787839  ...               1             0           0
# 1      18.097233  ...               3             0           0
# 2  111111.107200  ...              31             0           0
# 3      30.729368  ...               1             0           0
# 4     207.952195  ...               2             0           0
#
#    ct_flw_http_mthd  ct_src_ltm  ct_srv_dst  is_sm_ips_ports  attack_cat  \
# 0                 0           1           1                0    Exploits
# 1                 0           2           3                0      Normal
# 2                 0          20          31                0     Generic
# 3                 1           3           1                0      Normal
# 4                 0           2           4                0      Normal
#
#    label     Label
# 0      1  Exploits
# 1      0    Normal
# 2      1   Generic
# 3      0    Normal
# 4      0    Normal
#
# [5 rows x 46 columns]
#
# Test Dataset:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38652 entries, 0 to 38651
# Data columns (total 46 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 38652 non-null  int64
#  1   dur                38652 non-null  float64
#  2   proto              38652 non-null  object
#  3   service            38652 non-null  object
#  4   state              38652 non-null  object
#  5   spkts              38652 non-null  int64
#  6   dpkts              38652 non-null  int64
#  7   sbytes             38652 non-null  int64
#  8   dbytes             38652 non-null  int64
#  9   rate               38652 non-null  float64
#  10  sttl               38652 non-null  int64
#  11  dttl               38652 non-null  int64
#  12  sload              38652 non-null  float64
#  13  dload              38652 non-null  float64
#  14  sloss              38652 non-null  int64
#  15  dloss              38652 non-null  int64
#  16  sinpkt             38652 non-null  float64
#  17  dinpkt             38652 non-null  float64
#  18  sjit               38652 non-null  float64
#  19  djit               38652 non-null  float64
#  20  swin               38652 non-null  int64
#  21  stcpb              38652 non-null  int64
#  22  dtcpb              38652 non-null  int64
#  23  dwin               38652 non-null  int64
#  24  tcprtt             38652 non-null  float64
#  25  synack             38652 non-null  float64
#  26  ackdat             38652 non-null  float64
#  27  smean              38652 non-null  int64
#  28  dmean              38652 non-null  int64
#  29  trans_depth        38652 non-null  int64
#  30  response_body_len  38652 non-null  int64
#  31  ct_srv_src         38652 non-null  int64
#  32  ct_state_ttl       38652 non-null  int64
#  33  ct_dst_ltm         38652 non-null  int64
#  34  ct_src_dport_ltm   38652 non-null  int64
#  35  ct_dst_sport_ltm   38652 non-null  int64
#  36  ct_dst_src_ltm     38652 non-null  int64
#  37  is_ftp_login       38652 non-null  int64
#  38  ct_ftp_cmd         38652 non-null  int64
#  39  ct_flw_http_mthd   38652 non-null  int64
#  40  ct_src_ltm         38652 non-null  int64
#  41  ct_srv_dst         38652 non-null  int64
#  42  is_sm_ips_ports    38652 non-null  int64
#  43  attack_cat         38652 non-null  object
#  44  label              38652 non-null  int64
#  45  Label              38652 non-null  object
# dtypes: float64(11), int64(30), object(5)
# memory usage: 13.6+ MB
# None
#       id       dur proto service state  spkts  dpkts  sbytes  dbytes  \
# 0  63267  0.000004   udp     dns   INT      2      0     114       0
# 1  63021  8.847006   tcp     ftp   FIN     24     22    1276    1650
# 2  44087  0.382148   tcp       -   FIN     14      6    7858     268
# 3  53262  1.604105   tcp    http   FIN     10      8     862     354
# 4  14928  0.000008   udp     dns   INT      2      0     114       0
#
#             rate  ...  ct_dst_src_ltm  is_ftp_login  ct_ftp_cmd  \
# 0  250000.000600  ...               1             0           0
# 1       5.086467  ...               2             1           1
# 2      49.718957  ...               2             0           0
# 3      10.597810  ...               1             0           0
# 4  125000.000300  ...              36             0           0
#
#    ct_flw_http_mthd  ct_src_ltm  ct_srv_dst  is_sm_ips_ports      attack_cat  \
# 0                 0           2          11                0         Generic
# 1                 0           2           1                0        Exploits
# 2                 0           2           4                0         Fuzzers
# 3                 1           1           1                0  Reconnaissance
# 4                 0          19          36                0         Generic
#
#    label           Label
# 0      1         Generic
# 1      1        Exploits
# 2      1         Fuzzers
# 3      1  Reconnaissance
# 4      1         Generic
#
# [5 rows x 46 columns]
#
# Missing values in Train dataset:
# id                   0
# dur                  0
# proto                0
# service              0
# state                0
# spkts                0
# dpkts                0
# sbytes               0
# dbytes               0
# rate                 0
# sttl                 0
# dttl                 0
# sload                0
# dload                0
# sloss                0
# dloss                0
# sinpkt               0
# dinpkt               0
# sjit                 0
# djit                 0
# swin                 0
# stcpb                0
# dtcpb                0
# dwin                 0
# tcprtt               0
# synack               0
# ackdat               0
# smean                0
# dmean                0
# trans_depth          0
# response_body_len    0
# ct_srv_src           0
# ct_state_ttl         0
# ct_dst_ltm           0
# ct_src_dport_ltm     0
# ct_dst_sport_ltm     0
# ct_dst_src_ltm       0
# is_ftp_login         0
# ct_ftp_cmd           0
# ct_flw_http_mthd     0
# ct_src_ltm           0
# ct_srv_dst           0
# is_sm_ips_ports      0
# attack_cat           0
# label                0
# Label                0
# dtype: int64
#
# Missing values in Validation dataset:
# id                   0
# dur                  0
# proto                0
# service              0
# state                0
# spkts                0
# dpkts                0
# sbytes               0
# dbytes               0
# rate                 0
# sttl                 0
# dttl                 0
# sload                0
# dload                0
# sloss                0
# dloss                0
# sinpkt               0
# dinpkt               0
# sjit                 0
# djit                 0
# swin                 0
# stcpb                0
# dtcpb                0
# dwin                 0
# tcprtt               0
# synack               0
# ackdat               0
# smean                0
# dmean                0
# trans_depth          0
# response_body_len    0
# ct_srv_src           0
# ct_state_ttl         0
# ct_dst_ltm           0
# ct_src_dport_ltm     0
# ct_dst_sport_ltm     0
# ct_dst_src_ltm       0
# is_ftp_login         0
# ct_ftp_cmd           0
# ct_flw_http_mthd     0
# ct_src_ltm           0
# ct_srv_dst           0
# is_sm_ips_ports      0
# attack_cat           0
# label                0
# Label                0
# dtype: int64
#
# Missing values in Test dataset:
# id                   0
# dur                  0
# proto                0
# service              0
# state                0
# spkts                0
# dpkts                0
# sbytes               0
# dbytes               0
# rate                 0
# sttl                 0
# dttl                 0
# sload                0
# dload                0
# sloss                0
# dloss                0
# sinpkt               0
# dinpkt               0
# sjit                 0
# djit                 0
# swin                 0
# stcpb                0
# dtcpb                0
# dwin                 0
# tcprtt               0
# synack               0
# ackdat               0
# smean                0
# dmean                0
# trans_depth          0
# response_body_len    0
# ct_srv_src           0
# ct_state_ttl         0
# ct_dst_ltm           0
# ct_src_dport_ltm     0
# ct_dst_sport_ltm     0
# ct_dst_src_ltm       0
# is_ftp_login         0
# ct_ftp_cmd           0
# ct_flw_http_mthd     0
# ct_src_ltm           0
# ct_srv_dst           0
# is_sm_ips_ports      0
# attack_cat           0
# label                0
# Label                0
# dtype: int64
#
# Class distribution in Train dataset:
# Label
# Normal            65120
# Generic           41156
# Exploits          31063
# Fuzzers           16962
# DoS               11516
# Reconnaissance     9843
# Analysis           1875
# Backdoor           1647
# Shellcode          1059
# Worms               130
# Name: count, dtype: int64
#
# Class distribution in Validation dataset:
# Label
# Normal            13936
# Generic            8838
# Exploits           6767
# Fuzzers            3652
# DoS                2411
# Reconnaissance     2060
# Analysis            401
# Backdoor            331
# Shellcode           227
# Worms                27
# Name: count, dtype: int64
#
# Class distribution in Test dataset:
# Label
# Normal            13944
# Generic            8877
# Exploits           6695
# Fuzzers            3632
# DoS                2426
# Reconnaissance     2084
# Analysis            401
# Backdoor            351
# Shellcode           225
# Worms                17
# Name: count, dtype: int64

# %%
X_train, y_train, X_val, y_val, X_test, y_test, le, scaler, labels = preprocess_data(train_data, val_data, test_data)
# Out:
# Unique labels in train data: ['Normal' 'Analysis' 'Generic' 'Exploits' 'Fuzzers' 'DoS' 'Shellcode'
#  'Reconnaissance' 'Backdoor' 'Worms']
# Unique labels in validation data: ['Exploits' 'Normal' 'Generic' 'DoS' 'Reconnaissance' 'Fuzzers' 'Backdoor'
#  'Analysis' 'Shellcode' 'Worms']
# Unique labels in test data: ['Generic' 'Exploits' 'Fuzzers' 'Reconnaissance' 'Normal' 'DoS' 'Analysis'
#  'Backdoor' 'Shellcode' 'Worms']
#
# Fitting LabelEncoder on training labels...
# Classes found by LabelEncoder: ['Analysis' 'Backdoor' 'DoS' 'Exploits' 'Fuzzers' 'Generic' 'Normal'
#  'Reconnaissance' 'Shellcode' 'Worms']
#
# Encoding labels for train, validation, and test datasets...
#
# Encoded Train Labels (first 10): [6 0 5 5 6 6 5 6 3 3]
# Encoded Validation Labels (first 10): [3 6 5 6 6 6 6 6 6 3]
# Encoded Test Labels (first 10): [5 3 4 7 5 3 7 4 6 7]
#
# Processing features for the train dataset...
# Train features (numeric): (180371, 30)
# Train features (categorical): (180371, 4)
#
# Encoding categorical features in train data...
#
# Combined train features (before scaling):
#         id  spkts  dpkts  sbytes  dbytes  sttl  dttl  sloss  dloss  swin  ...  \
# 0   40306     42     42    2646   23508    31    29      7     14   255  ...
# 1   54787      2      0     200       0   254     0      0      0     0  ...
# 2  162958      2      0     114       0   254     0      0      0     0  ...
# 3  138931      2      0     114       0   254     0      0      0     0  ...
# 4   31409     14     18    1684   10168    31    29      3      5   255  ...
#
#    ct_ftp_cmd  ct_flw_http_mthd  ct_src_ltm  ct_srv_dst  is_sm_ips_ports  \
# 0           0                 0           3           4                0
# 1           0                 0           8           6                0
# 2           0                 0          18          17                0
# 3           0                 0          32          36                0
# 4           0                 1           1           2                0
#
#    label  proto  service  state  attack_cat
# 0      0    112        0      4           6
# 1      1     79        0      5           0
# 2      1    118        2      5           5
# 3      1    118        2      5           5
# 4      0    112        5      4           6
#
# [5 rows x 34 columns]
#
# Scaling train features...
# Scaled train features shape: (180371, 34)
#
# Processing features for the validation dataset...
# Validation features (numeric): (38650, 30)
# Validation features (categorical): (38650, 4)
#
# Encoding categorical features in validation data...
#
# Combined validation features (before scaling):
#         id  spkts  dpkts  sbytes  dbytes  sttl  dttl  sloss  dloss  swin  ...  \
# 0   88453     48      0    5184       0   254     0      0      0     0  ...
# 1   79299     10      6    2530     268   254   252      2      1   255  ...
# 2  122963      2      0     114       0   254     0      0      0     0  ...
# 3   25057     14     18    1684   10168    31    29      3      5   255  ...
# 4   12808    122    126    7814   16912    31    29     30     32   255  ...
#
#    ct_ftp_cmd  ct_flw_http_mthd  ct_src_ltm  ct_srv_dst  is_sm_ips_ports  \
# 0           0                 0           1           1                0
# 1           0                 0           2           3                0
# 2           0                 0          20          31                0
# 3           0                 1           3           1                0
# 4           0                 0           2           4                0
#
#    label  proto  service  state  attack_cat
# 0      1     78        0      5           3
# 1      0    112        0      3           6
# 2      1    118        2      4           5
# 3      0    112        5      3           6
# 4      0    112        0      3           6
#
# [5 rows x 34 columns]
#
# Scaling validation features...
# Scaled validation features shape: (38650, 34)
#
# Processing features for the test dataset...
# Test features (numeric): (38652, 30)
# Test features (categorical): (38652, 4)
#
# Encoding categorical features in test data...
#
# Combined test features (before scaling):
#        id  spkts  dpkts  sbytes  dbytes  sttl  dttl  sloss  dloss  swin  ...  \
# 0  63267      2      0     114       0   254     0      0      0     0  ...
# 1  63021     24     22    1276    1650    62   252      7      9   255  ...
# 2  44087     14      6    7858     268   254   252      4      1   255  ...
# 3  53262     10      8     862     354   254   252      2      1   255  ...
# 4  14928      2      0     114       0   254     0      0      0     0  ...
#
#    ct_ftp_cmd  ct_flw_http_mthd  ct_src_ltm  ct_srv_dst  is_sm_ips_ports  \
# 0           0                 0           2          11                0
# 1           1                 0           2           1                0
# 2           0                 0           2           4                0
# 3           0                 1           1           1                0
# 4           0                 0          19          36                0
#
#    label  proto  service  state  attack_cat
# 0      1    119        2      4           5
# 1      1    113        3      3           3
# 2      1    113        0      3           4
# 3      1    113        5      3           7
# 4      1    119        2      4           5
#
# [5 rows x 34 columns]
#
# Scaling test features...
# Scaled test features shape: (38652, 34)
#
# Final shapes of processed data:
# X_train shape: (180371, 34), y_train shape: (180371,)
# X_val shape: (38650, 34), y_val shape: (38650,)
# X_test shape: (38652, 34), y_test shape: (38652,)

# %%
def plot_class_distribution_(data, column='Label'):
    plt.rcParams.update({'font.size': 8})
    plt.figure(figsize=(12, 6))
    sns.countplot(x=column, data=data, palette='Set2')
    plt.title(f"Class Distribution in {column} Column", fontsize=14)
    plt.xlabel(column, fontsize=12)
    plt.ylabel('Count', fontsize=12)
    plt.tick_params(axis='both', labelsize=10)
    plt.yscale('log')
    plt.xticks(rotation=90)
    plt.grid(True)
    plt.show()

plot_class_distribution_(train_data)
# Out:
# /tmp/ipykernel_5121/432265042.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=column, data=data, palette='Set2')

# %%
numeric_features = train_data.select_dtypes(include=['int64', 'float64']).columns
plot_numeric_feature_distribution(train_data, numeric_features)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

def plot_correlation_matrix(data, numeric_features):
    correlation_matrix = data[numeric_features].corr()
    plt.figure(figsize=(40, 35))
    sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5, annot_kws={"size":10})

    plt.tick_params(axis='x', labelsize=10)
    plt.tick_params(axis='y', labelsize=10)
    
    plt.title("Correlation Matrix of Numeric Features", fontsize=22)
    plt.show()

numeric_features = train_data.select_dtypes(include=['float64', 'int64']).columns.tolist()
plot_correlation_matrix(train_data, numeric_features)
